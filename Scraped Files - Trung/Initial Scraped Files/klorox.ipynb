# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('1.csv')

# %%
for i in range(2, 33):
    data = data.append(pd.read_csv(str(i)+'.csv'))

# %%
len(data)
# Out:
# 11383

# %%
tomatoMeter = data['tomatoMeter']

# %%
pd.DataFrame.to_csv(data, 'final_data.csv')

# %%
data.append(data1)
# Out:
#     Unnamed: 0  dataIndex                               realTitle  \
# 0            0          0                               Toy Story
# 1            1          2                        Grumpier Old Men
# 2            2          3                       Waiting to Exhale
# 3            3          5                                    Heat
# 4            4          7                            Tom and Huck
# ..         ...        ...                                     ...
# 60          60      44662                           Saving Banksy
# 61          61      44663  The Exception (The Kaiser's Last Kiss)
# 62          62      44666                             Out of Time
# 63          63      44674             Goon: Last of the Enforcers
# 64          64      44678                                 Dunkirk
#
#                                      criticsConcensus tomatoMeter  \
# 0   Entertaining as it is innovative, Toy Story re...        100%
# ...

# %%
data[1629:1630]
# Out:
#      Unnamed: 0  dataIndex        realTitle criticsConcensus tomatoMeter  \
# 204         204       2864  Men Cry Bullets              NaN         40%
#
#      tomatoCount audienceScore  audienceCount  \
# 204           10           71%            799
#
#                                           realSynopsis  \
# 204  This role-reversal drama is about a man on the...
#
#                              rating    genreString        directedBy  \
# 204  NR (adult situations/language)  Comedy, Drama  Tamara Hernandez
#
#         studio      runTime                                    cast
# 204  Leo Films  105 minutes  Steven Nelson, Honey Lauren, Jeri Ryan
